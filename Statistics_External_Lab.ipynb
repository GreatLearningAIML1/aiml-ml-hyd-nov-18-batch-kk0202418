# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data

# %%
#Read the data set
data = pd.read_csv("Laliga.csv",skiprows=1)
data.head(10)
# Out:
#    Pos             Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86   4385        2762     1647        552
# 1    2        Barcelona       86   4262        2762     1581        573
# 2    3  Atletico Madrid       80   3442        2614     1241        598
# 3    4         Valencia       82   3386        2664     1187        616
# 4    5  Athletic Bilbao       86   3368        2762     1209        633
# 5    6          Sevilla       73   2819        2408      990        531
# 6    7         Espanyol       82   2792        2626      948        608
# 7    8    Real Sociedad       70   2573        2302      864        577
# 8    9         Zaragoza       58   2109        1986      698        522
# 9   10       Real Betis       51   1884        1728      606        440
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# ...

# %%
#replace dashes with 0 to make sure you can perform arithmetic operations on the data.
data=data.replace('-',0)
data
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %% [markdown]
# # 2. Print all the teams which have started playing between 1930-1980

# %%
data.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# dtype: object

# %%
data["PlayedYear"]=data['Since/LastApp'].str.split('-').str[0]

# %%
data.PlayedYear=data.PlayedYear.astype('int')
data.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# PlayedYear        int32
# dtype: object

# %%
data[(data.PlayedYear >=1930) & (data.PlayedYear <=1980)]
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 40   41         Burgos CF        6    168         204       59         50
# 41   42        Pontevedra        6    150         180       53         44
# 44   45            Arenas        7    107         130       43         21
# 49   50          Alcoyano        4     76         108       30         16
# 50   51              Jaen        3     71          90       29         13
# 51   52        Real Union        4     56          72       21         14
# 52   53        AD Almeria        2     52          68       17         18
# 53   54            Europa        3     42          54       18          6
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
#
#    GamesLost GoalsFor GoalsAgainst     ...     Runner-up Third Fourth Fifth  \
# ...

# %% [markdown]
# # 3. Print the list of teams which came Top 5 in terms of points

# %%
data.Points=data.Points.astype('int')
data.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points            int32
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# PlayedYear        int32
# dtype: object

# %%
data.sort_values('Points',ascending=False)
data.head(5)
# Out:
#    Pos             Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385        2762     1647        552
# 1    2        Barcelona       86    4262        2762     1581        573
# 2    3  Atletico Madrid       80    3442        2614     1241        598
# 3    4         Valencia       82    3386        2664     1187        616
# 4    5  Athletic Bilbao       86    3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst     ...     Runner-up Third Fourth Fifth  \
# 0       563     5947         3140     ...            23     8      8     3
# 1       608     5900         3114     ...            25    12     12     4
# 2       775     4534         3309     ...             8    16      9     7
# 3       861     4398         3469     ...             6    10     11    10
# 4       920     4631         3700     ...             7    10      5     8
#
#   Sixth   T    Debut Since/LastApp BestPosition  PlayedYear
# ...

# %% [markdown]
# # 4. Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference
#
# Goal_diff_count = GoalsFor - GoalsAgainst

# %%
data.GoalsFor=data.GoalsFor.astype('int')
data.GoalsAgainst=data.GoalsAgainst.astype('int')
data.dtypes
# Out:
# Pos               int64
# Team             object
# Seasons           int64
# Points            int32
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor          int32
# GoalsAgainst      int32
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Debut            object
# Since/LastApp    object
# BestPosition      int64
# PlayedYear        int32
# dtype: object

# %%
def Goal_diff_count():
    data['Goal difference'] = data['GoalsFor']-data['GoalsAgainst']
    return data

Goal_diff_count()
# Out:
#     Pos                 Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86    4385        2762     1647        552
# 1     2            Barcelona       86    4262        2762     1581        573
# 2     3      Atletico Madrid       80    3442        2614     1241        598
# 3     4             Valencia       82    3386        2664     1187        616
# 4     5      Athletic Bilbao       86    3368        2762     1209        633
# 5     6              Sevilla       73    2819        2408      990        531
# 6     7             Espanyol       82    2792        2626      948        608
# 7     8        Real Sociedad       70    2573        2302      864        577
# 8     9             Zaragoza       58    2109        1986      698        522
# 9    10           Real Betis       51    1884        1728      606        440
# 10   11  Deportivo La Coruna       45    1814        1530      563        392
# ...

# %%
data.tail(1)
# Out:
#     Pos    Team  Seasons  Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# 60   61  Girona        1       0           0        0          0         0
#
#     GoalsFor  GoalsAgainst       ...        Third Fourth Fifth Sixth  T  \
# 60         0             0       ...            0      0     0     0  0
#
#       Debut Since/LastApp BestPosition PlayedYear  Goal difference
# 60  2017-18       2017-18            9       2017                0
#
# [1 rows x 22 columns]

# %%
data.sort_values('Goal difference',ascending=False)
# Out:
#     Pos                 Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86    4385        2762     1647        552
# 1     2            Barcelona       86    4262        2762     1581        573
# 2     3      Atletico Madrid       80    3442        2614     1241        598
# 4     5      Athletic Bilbao       86    3368        2762     1209        633
# 3     4             Valencia       82    3386        2664     1187        616
# 5     6              Sevilla       73    2819        2408      990        531
# 20   21           Villarreal       17     970         646      266        172
# 60   61               Girona        1       0           0        0          0
# 7     8        Real Sociedad       70    2573        2302      864        577
# 55   56              Leganes        1      35          38        8         11
# 57   58               Condal        1      22          30        7          8
# ...

# %%
data.tail(1)
data.head(1)
# Out:
#    Pos         Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1  Real Madrid       86    4385        2762     1647        552
#
#   GamesLost  GoalsFor  GoalsAgainst       ...        Third Fourth Fifth Sixth  \
# 0       563      5947          3140       ...            8      8     3     4
#
#     T Debut Since/LastApp BestPosition PlayedYear  Goal difference
# 0  79  1929          1929            1       1929             2807
#
# [1 rows x 22 columns]

# %% [markdown]
# # 5. Create a new column with name “Winning Percent” and append it to the data set
#    Percentage of Winning = (GamesWon / GamesPlayed)*100
#    If there are any numerical error, replace it with 0%
#    Print the top 5 teams which has the highest Winning percentage

# %%
data.GamesWon=data.GamesWon.astype('int')
data.GamesPlayed=data.GamesPlayed.astype('int')
data['Winning percentage']=(data['GamesWon']/data['GamesPlayed']*100)
data['Winning percentage']=data['Winning percentage'].fillna(0)
data.sort_values('Winning percentage',ascending=False)
data.head(5)
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385         2762      1647        552
# 1    2        Barcelona       86    4262         2762      1581        573
# 2    3  Atletico Madrid       80    3442         2614      1241        598
# 3    4         Valencia       82    3386         2664      1187        616
# 4    5  Athletic Bilbao       86    3368         2762      1209        633
#
#   GamesLost  GoalsFor  GoalsAgainst         ...         Fourth Fifth Sixth  \
# 0       563      5947          3140         ...              8     3     4
# 1       608      5900          3114         ...             12     4     6
# 2       775      4534          3309         ...              9     7     6
# 3       861      4398          3469         ...             11    10     7
# 4       920      4631          3700         ...              5     8    10
#
# ...

# %% [markdown]
# # 6. Group teams based on their “Best position” and print the sum of their points for all positions
#
# Eg: Best Position                Points
#
#         1                              25000
#
#         2                              7000

# %%
data.groupby('BestPosition').sum()
# Out:
#               Pos  Seasons  Points  GamesPlayed  GamesWon  GoalsFor  \
# BestPosition
# 1              50      659   27933        21532      9888     36529
# 2              79      195    6904         6614      2255      8518
# 3              89      154    5221         4936      1732      6660
# 4             125      191    6563         6497      2097      7877
# 5             115       63    1884         2082       624      2370
# 6             158       62    2113         2052       624      2380
# 7             190       38    1186         1335       382      1379
# 8             154       31    1134         1120       319      1303
# 9             107        4      96          114        26       101
# 10            186       13     450          450       134       554
# 11             28       18     445          586       145       607
# 12             74       18     511          652       163       609
# 14             51        3      71           90        29       121
# ...
