# %% [markdown]
# ## Lab 2

# %% [markdown]
# Welcome to the second lab of the AIML!
# In addition to implementing code, there will be questions that you must answer which relate to the lab and your implementation. Each question you will answer is preceded by a **'Question X'** header. Carefully read each question and provide you answer or code in the following textboxes with **'Answer:'** header. Your lab submission will be evaluated based on your answers to each of the questions and the implementation you provide.

# %% [markdown]
# # Every question is of 1 mark.

# %% [markdown]
# ## Overview

# %% [markdown]
# This module covers,
#
# 1) One sample and Two sample t-tests
#
# 2) ANOVA
#
# 3) Type I and Type II errors
#
# 4) Probabilty Distributions
#
# 5) Linear Regression

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# The purpose of the test is to tell if there is any significant difference between two data sets.

# %% [markdown]
# ## Question 1
#
# *A student is trying to decide between two GPUs. He want to use the GPU for his research to run Deep learning algorithms, so the only thing he is concerned with is speed.*
#
# *He picks a Deep Learning algorithm on a large data set and runs it on both GPUs 15 times, timing each run in hours. Results are given in the below lists GPU1 and GPU2.*

# %% [markdown]
# Hint: You can import ttest function from scipy to perform t tests

# %% [markdown]
# Given,
#
# Null Hypothesis : There is no significant difference between data sets
#
# Alternate Hypothesis : There is a significant difference
#
# *Do two-sample testing and check whether to reject Null Hypothesis or not.*
#
# #### Answer:

# %%
import pandas as pd
from scipy.stats import ttest_1samp, ttest_ind, mannwhitneyu, levene, shapiro, f_oneway
from statsmodels.stats.power import ttest_power
import matplotlib.pyplot as plt

GPU1 = pd.DataFrame([11,9,10,11,10,12,9,11,12,9,11,12,9,10,9])
GPU2 = pd.DataFrame([11,13,10,13,12,9,11,12,12,11,12,12,10,11,13])


#Null Hypothesis : There is no significant difference between data sets
#Alternate Hypothesis : There is a significant difference

#Assumption: Both the datasets (GPU1 & GPU 2) are random, independent, parametric & normally distributed


t_statistic, p_value = ttest_ind(GPU1, GPU2)
print(t_statistic, p_value)
# Out:
# [-2.62762951] [0.01379428]

# %%
# p_value < 0.05 => alternative hypothesis: (considering 95% confidence level)
print ("p_value is less than 5%. Reject the Null hypothesis. p-value=", p_value)
# Out:
# p_value is less than 5%. Reject the Null hypothesis. p-value= [0.01379428]

# %% [markdown]
# [## Question 2
# ](https://)
# He is trying a third GPU which is GPU3.

# %%
GPU3 = pd.DataFrame([9,10,9,11,10,13,12,9,12,12,13,12,13,10,11])

# %% [markdown]
# *Do two-sample testing and check whether there is significant differene between speeds of two GPUs GPU1 and GPU3.*
#
# #### Answer:

# %%
#Assumption: Both the datasets (GPU1 & GPU 3) are random, independent, parametric & normally distributed
t_statistic, p_value = ttest_ind(GPU1, GPU3)
print(t_statistic, p_value)
# Out:
# [-1.49889438] [0.14509211]

# %%
# p_value > 0.05 => Null hypothesis: (considering 95% confidence level)
print ("p_value is greater than 5%. Do Not Reject the Null hypothesis. p-value=", p_value)
# Out:
# p_value is greater than 5%. Do Not Reject the Null hypothesis. p-value= [0.14509211]

# %% [markdown]
# ### ANOVA

# %% [markdown]
# ## Question 3
#
# If you need to compare more than two data sets at a time, an ANOVA is your best bet.
#
# *The results from three experiments with overlapping 95% confidence intervals are given below, and we want to confirm that the results for all three experiments are not significantly different.*
#
# #Assumption: All the 3 datasets (e1,e2 & e3) are random, independent, parametric & normally distributed
# But before conducting ANOVA, test equality of variances (using Levene's test) is satisfied or not. If not, then mention that we cannot depend on the result of ANOVA

# %%
import pandas as pd
e1 = pd.DataFrame([1.595440,1.419730,0.000000,0.000000])
e2 = pd.DataFrame([1.433800,2.079700,0.892139,2.384740])
e3 = pd.DataFrame([0.036930,0.938018,0.995956,1.006970])

# %% [markdown]
# Hint - You can use stats.levene function and stats.f_oneway function.

# %% [markdown]
# #### Answer:

# %%
# For checking equality of variance between groups
# Null Hypothesis: Variances are equal
levene(e1,e2,e3)
# Out:
# LeveneResult(statistic=array([2.67417257]), pvalue=array([0.12259793]))

# %%
# Null Hypothesis: All the three experiments are not significantly different.
f, p = f_oneway(e1,e2,e3)
print(f,p)
# Out:
# [2.51357623] [0.13574645]

# %%
# p_value > 0.05 => Null hypothesis: (considering 95% confidence level)
print ("Null Hypothesis: All the three experiments are not significantly different.")
print ("Since p_value is greater than 5%. Do Not Reject the Null hypothesis. p-value=", p_value)
# Out:
# Null Hypothesis: All the three experiments are not significantly different.
# Since p_value is greater than 5%. Do Not Reject the Null hypothesis. p-value= [0.01379428]

# %% [markdown]
# ## Question 4
#
# *In one or two sentences explain about **TypeI** and **TypeII** errors.*
#
# #### Answer:

# %% [markdown]
# type I error: rejection of a true null hypothesis (also known as a "false positive" finding)

# %% [markdown]
# type II error: failure to reject a false null hypothesis (also known as a "false negative" finding)

# %% [markdown]
# # Question 5
# You are a manager of a chinese restaurant. You want to determine whether the waiting time to place an order has changed in the past month from its previous population mean value of 4.5 minutes.
# State the null and alternative hypothesis.

# %% [markdown]
# #### Answer:

# %% [markdown]
# Null Hypothesis: Waiting time to place an order this month is same as past month

# %% [markdown]
# Alternate Hypothesis: Waiting time to place an order this month is not the same as past month

# %% [markdown]
# # Question 6
# Get the binomial distribution with n = 10, p = .7 and k = [0, 1, 2, 3, 4, 5, 6, 7]
#
# Hint - Use stats.binom.pmf() function for this.

# %%
from scipy.stats import binom
n = 10 
p = .7
k = [0, 1, 2, 3, 4, 5, 6, 7]
binomial=binom.pmf(k,n,p)
print (binomial)
# Out:
# [5.90490000e-06 1.37781000e-04 1.44670050e-03 9.00169200e-03
#  3.67569090e-02 1.02919345e-01 2.00120949e-01 2.66827932e-01]

# %% [markdown]
# # Question 7
# Plot the distribution created in the above question.

# %%
plt.plot(k,binomial)

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# Here we will try to see that if we can make a regression model to predict one column of a dataset by the use of other coloumn.
#
# ## Dataset
#
# Population of U.S. Cities
#
# ### Description
# The bigcity data frame has 49 rows and 2 columns.
#
# The measurements are the population (in 1000's) of 49 U.S. cities in 1920 and 1930. The 49 cities are a random sample taken from the 196 largest cities in 1920.
#
# ### Format
# This data frame contains the following columns:
#
# `u`
# The 1920 population.
#
# `x`
# The 1930 population.
#
# There is one unnamed column also in this dataset. Please remove and ignore that coloumn.
#
# Source
#
# The data were obtained from
#
# Cochran, W.G. (1977) Sampling Techniques. Third edition. John Wiley
#
# References
#
# Davison, A.C. and Hinkley, D.V. (1997) Bootstrap Methods and Their Application. Cambridge University Press.

# %% [markdown]
# # Question 8
# Read the dataset given in file named 'bigcity.csv'.

# %%
data=pd.read_csv("bigcity.csv")
data.head()
# Out:
#    Unnamed: 0    u    x
# 0           1  138  143
# 1           2   93  104
# 2           3   61   69
# 3           4  179  260
# 4           5   48   75

# %% [markdown]
# # Question 9 - Transform the dataset
# Find the number of rows in given dataset and separate the input(u column)  and target variables(x column) into X and Y.
#
# Remove the unnamed coloumn.
#
# Hint: You can shape function to get the size of the dataframe

# %%
print ("dataframe shape",data.shape)
print('Number of Rows = {0}'.format(data.shape[0]))
# Out:
# dataframe shape (49, 3)
# Number of Rows = 49

# %%
df=data.drop(data.columns[data.columns.str.contains('unnamed',case = False)],axis = 1)

# %% [markdown]
# ## Question 10 - Check the dataset for any missing values and also print out the correlation matrix

# %%
df.isna()
# Out:
#         u      x
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
# 15  False  False
# 16  False  False
# 17  False  False
# 18  False  False
# 19  False  False
# 20  False  False
# 21  False  False
# 22  False  False
# 23  False  False
# 24  False  False
# 25  False  False
# 26  False  False
# 27  False  False
# 28  False  False
# 29  False  False
# 30  False  False
# 31  False  False
# 32  False  False
# 33  False  False
# 34  False  False
# 35  False  False
# 36  False  False
# 37  False  False
# 38  False  False
# 39  False  False
# 40  False  False
# 41  False  False
# 42  False  False
# 43  False  False
# 44  False  False
# 45  False  False
# 46  False  False
# 47  False  False
# 48  False  False

# %% [markdown]
# You can use .isna() and .corr() functions to check NA's and correlation in the dataframe respectively

# %%
df.corr()
# Out:
#           u         x
# u  1.000000  0.981742
# x  0.981742  1.000000

# %%
df.describe()
# Out:
#                 u           x
# count   49.000000   49.000000
# mean   103.142857  127.795918
# std    104.405061  123.121211
# min      2.000000   46.000000
# 25%     43.000000   58.000000
# 50%     64.000000   79.000000
# 75%    120.000000  130.000000
# max    507.000000  634.000000

# %% [markdown]
# ### The high correlation betwwen u and x indicates that the variable u is a good predictor of variable x

# %% [markdown]
# # Question 11 - Split data into train, test sets
# Divide the data into training and test sets with 80-20 split using scikit-learn. Print the shapes of training and test feature sets.*

# %% [markdown]
# Check: train_test_split function

# %%
#Let us break the X and y dataframes into training set and test set. For this we will use
#Sklearn package's data splitting function which is based on random function

from sklearn.model_selection import train_test_split

# %%
# Import Linear Regression machine learning library
from sklearn.linear_model import LinearRegression

# %%
# Split X and y into training and test set in 80:20 ratio
X=df["u"]
y=df["x"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (39,)
# (39,)
# (10,)
# (10,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Question 12 - Find coefficients & intercept
# Estimate the coefficients b0 and b1 using scikit-learn.

# %%
# invoke the LinearRegression function and find the bestfit model on training data
X_train_2D=X_train.values.reshape(-1,1)
y_train_2D=y_train.values.reshape(-1,1)

regression_model = LinearRegression()
regression_model.fit(X_train_2D, y_train_2D)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# Check: coef_ and intercept_ functions can help you get coefficients & intercept

# %%
X_test_2D=X_test.values.reshape(-1,1)
predict=regression_model.predict(X_test_2D)
print('prediction is {0}'.format(predict))
# Out:
# prediction is [[167.40382318]
#  [148.85260343]
#  [ 60.73430963]
#  [ 51.45869975]
#  [ 80.44498061]
#  [217.26022625]
#  [ 56.09650469]
#  [306.53797128]
#  [ 59.57485839]
#  [118.70687134]]

# %%
b1=regression_model.intercept_
b0=regression_model.coef_

print('coefficients is {0}'.format(b0))
print('Intercept is {0}'.format(b1))
# Out:
# coefficients is [[1.15945123]]
# Intercept is [9.71845532]

# %% [markdown]
# # Question 13 - Linear Relationship between feature and target
# Plot the line with b1 and b0 as slope and y-intercept.
#
# Hint - y = mx + c, plot y

# %%
X_train.shape
# Out:
# (39,)

# %%
y = b0*X_train.values+b1
print (y)
# Out:
# [[ 51.45869975 150.01205466  79.28552938 209.14406761 458.42608296
#    74.64772444  86.24223678  56.09650469 597.56023107  38.70473618
#    83.92333431  97.83674912 110.5907127   98.99620036  67.69101703
#    65.37211457  61.89376086 355.23492312  53.77760222 291.46510524
#   196.39010403  87.40168802 451.46937556 100.15565159  83.92333431
#    43.34254112  36.38583371  59.57485839 117.54742011  67.69101703
#   169.72272564  95.51784665  52.61815099  63.0532121   12.03735779
#    44.50199235  92.03949295 144.21479849  63.0532121 ]]

# %%
plt.plot(X_test.values,predict)

# %% [markdown]
# # Question 14 - Evaluation of model with scikit-learn
# Validate the model with Root Mean Squares error and R^2 score using scikit-learn. RMSE and R2 for test data and prediction

# %% [markdown]
# Hint: You can import mean_squared_error function & r2 (R square) from sklearn.metrics. Performing root operation over mean square error over mean square error gives you root mean square error

# %%
#y_pred = lm.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt

mse = mean_squared_error(y_test, predict)

rmse = sqrt(mse)
print (rmse)
# Out:
# 23.385235190249123

# %%
# Model score - R2 or coeff of determinant
R2=r2_score(y_test, predict)
print (R2)
# Out:
# 0.9181922560396981

# %% [markdown]
# ## Question 15 - Calculate the accuracy of the model for both training and test data set

# %% [markdown]
# ### Hint: .score() function

# %%
regression_model.score(X_train_2D, y_train_2D)
# Out:
# 0.9682175540860046

# %%
regression_model.score(X_test_2D, y_test)
# Out:
# 0.9181922560396981

# %%
# So the model explains 91.8% of the variability in Y using X
